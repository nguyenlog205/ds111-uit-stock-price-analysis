# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# %% [markdown]
# # 1. Data Preparation

# %%
df = pd.read_csv(r'..\..\data\preprocessed_dataset.csv')
df.head(5)
# Out:
#          date  cpi_rate  xau_usd_rate_log_return  pe_ratio_log_return  \
# 0  2020-01-01    0.0643                 0.999818            -0.020095
# 1  2020-01-02    0.0643                 0.999818            -0.020095
# 2  2020-01-03    0.0643                 1.626549            -0.020095
# 3  2020-01-06    0.0643                 2.133883            -0.020095
# 4  2020-01-07    0.0643                -0.470972            -0.020095
#
#    fpt_stock_price     gdp_value  fpt_stock_price_log_return  \
# 0            21.39  3.466157e+11                   -0.055765
# 1            21.39  3.466157e+11                   -0.055765
# 2            21.03  3.466157e+11                   -1.040504
# 3            20.81  3.466157e+11                   -0.665883
# 4            21.21  3.466157e+11                    1.048811
#
#    cpi_rate_log_return  usd_vnd_rate_log_return  fpt_stock_volume_log_return
# 0              0.01877                 0.067868                    -0.003521
# 1              0.01877                 0.067868                    -0.003521
# 2              0.01877                -0.081355                     1.709207
# 3              0.01877                 0.040724                    -1.308273
# 4              0.01877                -0.027099                    -0.553839

# %%
scaler_fpt = StandardScaler()
scaler_gdp = StandardScaler()

def process_data(dataset, is_train=True):
    df_out = dataset.copy()
    
    col_fpt = ['fpt_stock_price']
    col_gdp = ['gdp_value']

    if is_train:
        df_out[col_fpt] = scaler_fpt.fit_transform(df_out[col_fpt])
        df_out[col_gdp] = scaler_gdp.fit_transform(df_out[col_gdp])
    else:
        df_out[col_fpt] = scaler_fpt.transform(df_out[col_fpt])
        df_out[col_gdp] = scaler_gdp.transform(df_out[col_gdp])
        
    return df_out

# %% [markdown]
# ## 1.1. Separate Dataset

# %%
_train, _test = train_test_split(df, test_size=0.15, shuffle=False)

train = process_data(_train, is_train=True)
test = process_data(_test, is_train=False)

# %%
TARGET_COL = 'fpt_stock_price'
REMOVED = 'fpt_stock_price_log_return'

# --- Tách tập TRAIN ---
X_train = train.drop(columns=[TARGET_COL, 'date', REMOVED])
y_train = train[TARGET_COL]

# --- Tách tập TEST ---
X_test = test.drop(columns=[TARGET_COL, 'date', REMOVED])
y_test = test[TARGET_COL]

print("Đã tách dữ liệu thành X_train, y_train, X_test, y_test thành công!")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Đã tách dữ liệu thành X_train, y_train, X_test, y_test thành công!
# X_train shape: (1299, 7)
# y_train shape: (1299,)

# %% [markdown]
# ## 1.2. Tensor Import

# %%
class CustomDataset(Dataset):
    def __init__(self, X_data: pd.DataFrame, Y_data: pd.Series):
        X_numpy = X_data.values
        Y_numpy = Y_data.values
        if Y_numpy.ndim == 1:
            Y_numpy = Y_numpy.reshape(-1, 1)
        self.X_tensor = torch.tensor(X_numpy, dtype=torch.float32).unsqueeze(1)
        self.Y_tensor = torch.tensor(Y_numpy, dtype=torch.float32)
        
    def __len__(self):
        """Trả về tổng số samples."""
        return len(self.X_tensor)
    
    def __getitem__(self, idx):
        """Trả về cặp (feature, target) cho index."""
        return self.X_tensor[idx], self.Y_tensor[idx]

# %%
train_dataset = CustomDataset(X_train, y_train)
test_dataset = CustomDataset(X_test, y_test)
BATCH_SIZE = 64 

train_loader = DataLoader(
    dataset=train_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False 
)

test_loader = DataLoader(
    dataset=test_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False
)

print("-" * 50)
print("✅ Đã tạo DataLoader thành công.")
print(f"Tổng số batch cho Train: {len(train_loader)}")
print(f"Tổng số batch cho Test: {len(test_loader)}")
# Out:
# --------------------------------------------------
# ✅ Đã tạo DataLoader thành công.
# Tổng số batch cho Train: 21
# Tổng số batch cho Test: 4

# %% [markdown]
# ## 1.3. Model

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm = nn.LSTM(
            input_size, 
            hidden_size, 
            num_layers, 
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))  
        out = self.fc(out[:, -1, :])
        
        return out

# %% [markdown]
# # 2. Training

# %% [markdown]
# ## 2.1. Configuration

# %%
INPUT_SIZE = X_train.shape[1]
HIDDEN_SIZE = 32
NUM_LAYERS = 1
OUTPUT_SIZE = 1

# %%
model = LSTMModel(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, OUTPUT_SIZE)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print(f"✅ Đã định nghĩa và khởi tạo mô hình LSTM ({NUM_LAYERS} lớp) trên {device}.")
print("\n--- Cấu trúc Mô hình ---")
print(model)
# Out:
# ✅ Đã định nghĩa và khởi tạo mô hình LSTM (1 lớp) trên cuda.
#
# --- Cấu trúc Mô hình ---
# LSTMModel(
#   (lstm): LSTM(7, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# ## 2.2. Training

# %%
import torch.nn as nn
import torch.optim as optim
import torch

loss_fn = nn.MSELoss() 
LEARNING_RATE = 0.001
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
def train_model(model, train_loader, test_loader, loss_fn, optimizer, num_epochs, device, 
                      patience=100): 
    """
    Huấn luyện mô hình với Early Stopping và Model Checkpointing (chỉ dựa trên Test Loss).
    
    Args:
        patience (int): Số epochs tối đa Test Loss không được cải thiện.
    """
    
    # Khởi tạo giá trị tốt nhất và bộ đếm Early Stopping
    best_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None
    
    model.train() 
    for epoch in range(num_epochs):
        train_loss = 0.0
        
        # --- TRAINING LOOP (Forward -> Backward -> Optimize) ---
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * X_batch.size(0)
            
        # --- VALIDATION LOOP (Checkpointing và Early Stopping) ---
        model.eval() 
        test_loss = 0.0
        
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                y_pred = model(X_batch)
                loss = loss_fn(y_pred, y_batch)
                test_loss += loss.item() * X_batch.size(0)
        
        # Tính Average Loss
        train_loss /= len(train_loader.dataset)
        test_loss /= len(test_loader.dataset)
        
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Test Loss: {test_loss:.6f}')
        
        # 1. Kiểm tra Checkpointing (Lưu mô hình tốt nhất)
        if test_loss < best_loss:
            best_loss = test_loss
            epochs_no_improve = 0
            # Lưu trạng thái mô hình tốt nhất (trọng số)
            best_model_state = model.state_dict() 
            print(f"   [Checkpoint] Test Loss giảm ({best_loss:.6f}). Lưu mô hình.")
        else:
            epochs_no_improve += 1
            
        # 2. Kiểm tra Early Stopping
        if epochs_no_improve >= patience:
            print(f"🛑 STOPPING: Early Stop kích hoạt. Test Loss không cải thiện sau {patience} epochs.")
            break
            
        model.train() # Quay lại chế độ train

    # Tải lại mô hình tốt nhất đã lưu trước khi kết thúc
    if best_model_state:
        model.load_state_dict(best_model_state)
        print("✅ Tải lại trạng thái mô hình tốt nhất.")
        
    return model

# %%
EPOCHS = 500
train_model(model, train_loader, test_loader, loss_fn, optimizer, EPOCHS, device) 

print("✅ Đã viết xong hàm train_model. Bước tiếp theo là gọi hàm này để bắt đầu huấn luyện.")
# Out:
# Epoch [1/500], Train Loss: 1.056708, Test Loss: 4.472270
#    [Checkpoint] Test Loss giảm (4.472270). Lưu mô hình.
# Epoch [2/500], Train Loss: 0.994016, Test Loss: 4.284080
#    [Checkpoint] Test Loss giảm (4.284080). Lưu mô hình.
# Epoch [3/500], Train Loss: 0.955955, Test Loss: 4.089233
#    [Checkpoint] Test Loss giảm (4.089233). Lưu mô hình.
# Epoch [4/500], Train Loss: 0.918635, Test Loss: 3.884698
#    [Checkpoint] Test Loss giảm (3.884698). Lưu mô hình.
# Epoch [5/500], Train Loss: 0.879382, Test Loss: 3.663580
#    [Checkpoint] Test Loss giảm (3.663580). Lưu mô hình.
# Epoch [6/500], Train Loss: 0.837031, Test Loss: 3.421269
#    [Checkpoint] Test Loss giảm (3.421269). Lưu mô hình.
# Epoch [7/500], Train Loss: 0.791024, Test Loss: 3.156021
#    [Checkpoint] Test Loss giảm (3.156021). Lưu mô hình.
# Epoch [8/500], Train Loss: 0.741340, Test Loss: 2.869170
#    [Checkpoint] Test Loss giảm (2.869170). Lưu mô hình.
# Epoch [9/500], Train Loss: 0.688524, Test Loss: 2.565297
#    [Checkpoint] Test Loss giảm (2.565297). Lưu mô hình.
# Epoch [10/500], Train Loss: 0.633702, Test Loss: 2.252197
#    [Checkpoint] Test Loss giảm (2.252197). Lưu mô hình.
# Epoch [11/500], Train Loss: 0.578542, Test Loss: 1.940375
#    [Checkpoint] Test Loss giảm (1.940375). Lưu mô hình.
# Epoch [12/500], Train Loss: 0.525098, Test Loss: 1.641859
#    [Checkpoint] Test Loss giảm (1.641859). Lưu mô hình.
# Epoch [13/500], Train Loss: 0.475526, Test Loss: 1.368386
#    [Checkpoint] Test Loss giảm (1.368386). Lưu mô hình.
# Epoch [14/500], Train Loss: 0.431722, Test Loss: 1.129402
#    [Checkpoint] Test Loss giảm (1.129402). Lưu mô hình.
# Epoch [15/500], Train Loss: 0.394989, Test Loss: 0.930512
#    [Checkpoint] Test Loss giảm (0.930512). Lưu mô hình.
# Epoch [16/500], Train Loss: 0.365840, Test Loss: 0.772872
#    [Checkpoint] Test Loss giảm (0.772872). Lưu mô hình.
# Epoch [17/500], Train Loss: 0.343988, Test Loss: 0.653667
#    [Checkpoint] Test Loss giảm (0.653667). Lưu mô hình.
# Epoch [18/500], Train Loss: 0.328518, Test Loss: 0.567389
#    [Checkpoint] Test Loss giảm (0.567389). Lưu mô hình.
# Epoch [19/500], Train Loss: 0.318172, Test Loss: 0.507367
#    [Checkpoint] Test Loss giảm (0.507367). Lưu mô hình.
# Epoch [20/500], Train Loss: 0.311626, Test Loss: 0.467060
#    [Checkpoint] Test Loss giảm (0.467060). Lưu mô hình.
# Epoch [21/500], Train Loss: 0.307698, Test Loss: 0.440850
#    [Checkpoint] Test Loss giảm (0.440850). Lưu mô hình.
# Epoch [22/500], Train Loss: 0.305453, Test Loss: 0.424345
#    [Checkpoint] Test Loss giảm (0.424345). Lưu mô hình.
# Epoch [23/500], Train Loss: 0.304219, Test Loss: 0.414337
#    [Checkpoint] Test Loss giảm (0.414337). Lưu mô hình.
# Epoch [24/500], Train Loss: 0.303550, Test Loss: 0.408600
#    [Checkpoint] Test Loss giảm (0.408600). Lưu mô hình.
# Epoch [25/500], Train Loss: 0.303169, Test Loss: 0.405643
#    [Checkpoint] Test Loss giảm (0.405643). Lưu mô hình.
# Epoch [26/500], Train Loss: 0.302915, Test Loss: 0.404491
#    [Checkpoint] Test Loss giảm (0.404491). Lưu mô hình.
# Epoch [27/500], Train Loss: 0.302703, Test Loss: 0.404516
# Epoch [28/500], Train Loss: 0.302489, Test Loss: 0.405319
# Epoch [29/500], Train Loss: 0.302256, Test Loss: 0.406645
# Epoch [30/500], Train Loss: 0.302000, Test Loss: 0.408332
# Epoch [31/500], Train Loss: 0.301720, Test Loss: 0.410279
# Epoch [32/500], Train Loss: 0.301422, Test Loss: 0.412420
# Epoch [33/500], Train Loss: 0.301109, Test Loss: 0.414714
# Epoch [34/500], Train Loss: 0.300787, Test Loss: 0.417134
# Epoch [35/500], Train Loss: 0.300458, Test Loss: 0.419664
# Epoch [36/500], Train Loss: 0.300127, Test Loss: 0.422293
# Epoch [37/500], Train Loss: 0.299794, Test Loss: 0.425013
# Epoch [38/500], Train Loss: 0.299461, Test Loss: 0.427821
# Epoch [39/500], Train Loss: 0.299131, Test Loss: 0.430713
# Epoch [40/500], Train Loss: 0.298804, Test Loss: 0.433686
# Epoch [41/500], Train Loss: 0.298481, Test Loss: 0.436740
# Epoch [42/500], Train Loss: 0.298161, Test Loss: 0.439873
# Epoch [43/500], Train Loss: 0.297846, Test Loss: 0.443083
# Epoch [44/500], Train Loss: 0.297535, Test Loss: 0.446370
# Epoch [45/500], Train Loss: 0.297229, Test Loss: 0.449732
# Epoch [46/500], Train Loss: 0.296927, Test Loss: 0.453169
# Epoch [47/500], Train Loss: 0.296630, Test Loss: 0.456680
# Epoch [48/500], Train Loss: 0.296338, Test Loss: 0.460263
# Epoch [49/500], Train Loss: 0.296050, Test Loss: 0.463918
# Epoch [50/500], Train Loss: 0.295766, Test Loss: 0.467643
# Epoch [51/500], Train Loss: 0.295486, Test Loss: 0.471437
# Epoch [52/500], Train Loss: 0.295210, Test Loss: 0.475299
# Epoch [53/500], Train Loss: 0.294939, Test Loss: 0.479228
# Epoch [54/500], Train Loss: 0.294671, Test Loss: 0.483224
# Epoch [55/500], Train Loss: 0.294406, Test Loss: 0.487285
# Epoch [56/500], Train Loss: 0.294146, Test Loss: 0.491409
# Epoch [57/500], Train Loss: 0.293888, Test Loss: 0.495597
# Epoch [58/500], Train Loss: 0.293634, Test Loss: 0.499846
# Epoch [59/500], Train Loss: 0.293384, Test Loss: 0.504156
# Epoch [60/500], Train Loss: 0.293136, Test Loss: 0.508526
# Epoch [61/500], Train Loss: 0.292891, Test Loss: 0.512955
# Epoch [62/500], Train Loss: 0.292650, Test Loss: 0.517442
# Epoch [63/500], Train Loss: 0.292411, Test Loss: 0.521987
# Epoch [64/500], Train Loss: 0.292175, Test Loss: 0.526587
# Epoch [65/500], Train Loss: 0.291941, Test Loss: 0.531243
# Epoch [66/500], Train Loss: 0.291710, Test Loss: 0.535953
# Epoch [67/500], Train Loss: 0.291482, Test Loss: 0.540717
# Epoch [68/500], Train Loss: 0.291256, Test Loss: 0.545534
# Epoch [69/500], Train Loss: 0.291032, Test Loss: 0.550403
# Epoch [70/500], Train Loss: 0.290810, Test Loss: 0.555323
# Epoch [71/500], Train Loss: 0.290591, Test Loss: 0.560293
# Epoch [72/500], Train Loss: 0.290374, Test Loss: 0.565314
# Epoch [73/500], Train Loss: 0.290159, Test Loss: 0.570383
# Epoch [74/500], Train Loss: 0.289945, Test Loss: 0.575501
# Epoch [75/500], Train Loss: 0.289734, Test Loss: 0.580666
# Epoch [76/500], Train Loss: 0.289525, Test Loss: 0.585878
# Epoch [77/500], Train Loss: 0.289317, Test Loss: 0.591137
# Epoch [78/500], Train Loss: 0.289112, Test Loss: 0.596442
# Epoch [79/500], Train Loss: 0.288908, Test Loss: 0.601792
# Epoch [80/500], Train Loss: 0.288705, Test Loss: 0.607186
# Epoch [81/500], Train Loss: 0.288505, Test Loss: 0.612624
# Epoch [82/500], Train Loss: 0.288306, Test Loss: 0.618106
# Epoch [83/500], Train Loss: 0.288108, Test Loss: 0.623631
# Epoch [84/500], Train Loss: 0.287912, Test Loss: 0.629198
# Epoch [85/500], Train Loss: 0.287718, Test Loss: 0.634807
# Epoch [86/500], Train Loss: 0.287525, Test Loss: 0.640458
# Epoch [87/500], Train Loss: 0.287333, Test Loss: 0.646149
# Epoch [88/500], Train Loss: 0.287143, Test Loss: 0.651881
# Epoch [89/500], Train Loss: 0.286954, Test Loss: 0.657653
# Epoch [90/500], Train Loss: 0.286766, Test Loss: 0.663465
# Epoch [91/500], Train Loss: 0.286580, Test Loss: 0.669315
# Epoch [92/500], Train Loss: 0.286395, Test Loss: 0.675205
# Epoch [93/500], Train Loss: 0.286211, Test Loss: 0.681132
# Epoch [94/500], Train Loss: 0.286029, Test Loss: 0.687098
# Epoch [95/500], Train Loss: 0.285848, Test Loss: 0.693101
# Epoch [96/500], Train Loss: 0.285667, Test Loss: 0.699141
# Epoch [97/500], Train Loss: 0.285488, Test Loss: 0.705218
# Epoch [98/500], Train Loss: 0.285311, Test Loss: 0.711331
# Epoch [99/500], Train Loss: 0.285134, Test Loss: 0.717480
# Epoch [100/500], Train Loss: 0.284958, Test Loss: 0.723664
# Epoch [101/500], Train Loss: 0.284783, Test Loss: 0.729884
# Epoch [102/500], Train Loss: 0.284610, Test Loss: 0.736138
# Epoch [103/500], Train Loss: 0.284437, Test Loss: 0.742427
# Epoch [104/500], Train Loss: 0.284266, Test Loss: 0.748750
# Epoch [105/500], Train Loss: 0.284095, Test Loss: 0.755107
# Epoch [106/500], Train Loss: 0.283925, Test Loss: 0.761497
# Epoch [107/500], Train Loss: 0.283757, Test Loss: 0.767920
# Epoch [108/500], Train Loss: 0.283589, Test Loss: 0.774376
# Epoch [109/500], Train Loss: 0.283422, Test Loss: 0.780865
# Epoch [110/500], Train Loss: 0.283256, Test Loss: 0.787386
# Epoch [111/500], Train Loss: 0.283091, Test Loss: 0.793938
# Epoch [112/500], Train Loss: 0.282927, Test Loss: 0.800522
# Epoch [113/500], Train Loss: 0.282764, Test Loss: 0.807137
# Epoch [114/500], Train Loss: 0.282602, Test Loss: 0.813783
# Epoch [115/500], Train Loss: 0.282440, Test Loss: 0.820459
# Epoch [116/500], Train Loss: 0.282280, Test Loss: 0.827165
# Epoch [117/500], Train Loss: 0.282120, Test Loss: 0.833902
# Epoch [118/500], Train Loss: 0.281961, Test Loss: 0.840668
# Epoch [119/500], Train Loss: 0.281802, Test Loss: 0.847463
# Epoch [120/500], Train Loss: 0.281645, Test Loss: 0.854288
# Epoch [121/500], Train Loss: 0.281488, Test Loss: 0.861141
# Epoch [122/500], Train Loss: 0.281332, Test Loss: 0.868023
# Epoch [123/500], Train Loss: 0.281177, Test Loss: 0.874933
# Epoch [124/500], Train Loss: 0.281022, Test Loss: 0.881871
# Epoch [125/500], Train Loss: 0.280869, Test Loss: 0.888836
# Epoch [126/500], Train Loss: 0.280716, Test Loss: 0.895829
# 🛑 STOPPING: Early Stop kích hoạt. Test Loss không cải thiện sau 100 epochs.
# ✅ Tải lại trạng thái mô hình tốt nhất.
# ✅ Đã viết xong hàm train_model. Bước tiếp theo là gọi hàm này để bắt đầu huấn luyện.

# %% [markdown]
# # 3. Predicting

# %%
import torch
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

def predict(model, loader, scaler_target, device):
    """
    Dự đoán và Inverse Transform để lấy Giá thô trên tập Test.
    Tính và in R-squared, RMSE, và MAE ra màn hình.
    
    Returns:
        y_pred_raw_price (np.ndarray): Predicted Price (Unscaled).
        y_test_raw_price (np.ndarray): Actual Price (Unscaled).
        time_index (np.ndarray): Index tuần tự.
        r2 (float): Hệ số R-squared.
        rmse (float): RMSE.
        mae (float): MAE.
    """
    model.eval() 
    
    predictions = []
    actuals = []
    
    # 1. Chạy Inference (Dự đoán)
    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            
            y_pred = model(X_batch)
            
            predictions.append(y_pred.cpu().numpy())
            actuals.append(y_batch.cpu().numpy())

    # 2. Ghép các lô (batches) lại và Đảo ngược chuẩn hóa
    y_pred_scaled = np.concatenate(predictions, axis=0)
    y_test_scaled = np.concatenate(actuals, axis=0)

    # Đảo ngược chuẩn hóa để lấy Giá thô (Unscaled Price)
    y_pred_raw_price = scaler_target.inverse_transform(y_pred_scaled)
    y_test_raw_price = scaler_target.inverse_transform(y_test_scaled)
    
    # 3. Tính các chỉ số (trên dữ liệu Giá thô)
    y_pred_flat = y_pred_raw_price.flatten()
    y_test_flat = y_test_raw_price.flatten()
    
    rmse = np.sqrt(mean_squared_error(y_test_flat, y_pred_flat))
    mae = mean_absolute_error(y_test_flat, y_pred_flat)
    r2 = r2_score(y_test_flat, y_pred_flat)
    
    time_index = np.arange(len(y_pred_raw_price))
    
    print("\n✅ Dự đoán và Đảo ngược chuẩn hóa Giá (Price) hoàn tất.")
    print(f"📈 Hệ số R-squared trên tập Test (Giá Thô): {r2:.4f}")
    print(f"📉 Giá trị RMSE (Lỗi TB Bình phương Gốc): {rmse:.4f}")
    print(f"📉 Giá trị MAE (Lỗi Tuyệt đối TB): {mae:.4f}")
    
    # THAY ĐỔI: Trả về các chỉ số đánh giá và Price
    return y_pred_raw_price, y_test_raw_price, time_index, r2, rmse, mae

# %%
y_predict, y_test, time, r2, rmse, mae = predict(
    model = model,
    loader = test_loader,
    scaler_target=scaler_fpt,
    device = 'cuda'
)
# Out:
# ✅ Dự đoán và Đảo ngược chuẩn hóa Giá (Price) hoàn tất.
# 📈 Hệ số R-squared trên tập Test (Giá Thô): -3.3707
# 📉 Giá trị RMSE (Lỗi TB Bình phương Gốc): 25.1709
# 📉 Giá trị MAE (Lỗi Tuyệt đối TB): 22.6520

# %% [markdown]
# # 4. Visualize

# %%
plt.figure(figsize=(18, 8))

# Đường Log Return thực tế (Actual)
plt.plot(time, y_test.flatten(), 
         label='Log Return thực tế (Actual)', color='blue', linewidth=2)

# Đường Log Return dự đoán (Predicted)
plt.plot(time, y_predict.flatten(), 
         label='Log Return dự đoán (Predicted)', color='red', linestyle='--', linewidth=1.5)

# Thêm chi tiết biểu đồ
plt.title('So sánh Log Returns thực tế và Dự đoán (LSTM - Tập Test)', fontsize=16)
plt.xlabel('Chỉ mục thời gian (Time Index)', fontsize=12) 
plt.ylabel('Giá trị Log Return', fontsize=12)
plt.legend(loc='upper left', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()
